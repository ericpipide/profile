# %%
import platform,os,wmi,GPUtil
import psutil as ps
#進程資訊
ps.pids()
# Out:
# [0,
#  4,
#  240,
#  1012,
#  1180,
#  1196,
#  1396,
#  1408,
#  1412,
#  1416,
#  1548,
#  1552,
#  1560,
#  1636,
#  1688,
#  1708,
#  1784,
#  1824,
#  1852,
#  1932,
#  1980,
#  1992,
#  2180,
#  2188,
#  2244,
#  2292,
#  2320,
#  2348,
#  2384,
#  2500,
#  2536,
#  2644,
#  2668,
#  2720,
#  2780,
#  2844,
#  2876,
#  2892,
#  2920,
#  2940,
#  3048,
#  3128,
#  3172,
#  3188,
#  3208,
#  3216,
#  3304,
#  3500,
#  3504,
#  3516,
#  3524,
#  3548,
#  3636,
#  3692,
#  3716,
#  3820,
#  3884,
#  3916,
#  3988,
#  4028,
#  4332,
#  4444,
#  4448,
#  4456,
#  4480,
#  4500,
#  4540,
#  4548,
#  4556,
#  4584,
#  4596,
#  4836,
#  4900,
#  4908,
#  4916,
#  4928,
#  4976,
#  5168,
#  5196,
#  5216,
#  5248,
#  5348,
#  5376,
#  5424,
#  5452,
#  5480,
#  5600,
#  5616,
#  5656,
#  5676,
#  5700,
#  5752,
#  5836,
#  5864,
#  5884,
#  5956,
#  5964,
#  5972,
#  5980,
#  5988,
#  5996,
#  6004,
#  6012,
#  6020,
#  6028,
#  6036,
#  6044,
#  6052,
#  6060,
#  6072,
#  6084,
# ...

# %%
p = ps.Process(3884)
print(p.exe())
print(p.name())
print(p.status())
print(p.cpu_times())
print(p.memory_info())
print(p.num_threads())
# Out:
# C:\Users\eric0\AppData\Local\Programs\Microsoft VS Code\Code.exe
# Code.exe
# running
# pcputimes(user=17.25, system=22.15625, children_user=0.0, children_system=0.0)
# pmem(rss=153817088, vms=86446080, num_page_faults=251470, peak_wset=164048896, wset=153817088, peak_paged_pool=1187744, paged_pool=1081064, peak_nonpaged_pool=224888, nonpaged_pool=58984, pagefile=86446080, peak_pagefile=108269568, private=86446080)
# 35

# %%
GPUtil.showUtilization()
